# %% [markdown]
# # 2 - Model Training
#
# Temiz veri üretimini, özellik çıkarımını, model eğitimini, grafikleri ve artifact kayıtlarını tek komutla çalıştırır.

# %%
import sys
from pathlib import Path

BASE_DIR = Path.cwd().resolve().parent if Path.cwd().name == 'src' else Path.cwd().resolve()
sys.path.insert(0, str(BASE_DIR / 'src'))

from url_guard.train import train_project

metrics = train_project(BASE_DIR)
metrics
